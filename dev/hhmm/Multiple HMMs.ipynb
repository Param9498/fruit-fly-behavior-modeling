# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os

# %%
data_folder = '../../data'

categories = pd.read_csv(f'{data_folder}/categories.csv', header = None)
avel = pd.read_csv(f'{data_folder}/hhmm_avel.csv', header = None)
fvel = pd.read_csv(f'{data_folder}/hhmm_fvel.csv', header = None)

# %%
avel.shape
# Out:
# (499, 328)

# %%
fvel.shape
# Out:
# (500, 328)

# %%
categories.shape
# Out:
# (500, 328)

# %%
data_folder = '../../data'
with open(os.path.join(data_folder, 'all_data.npy'), 'rb') as f:
    np_data = np.load(f)

# %%
np_data.shape
# Out:
# (362, 3500, 8)

# %%
pd.DataFrame(np_data[:, 30*50:40*50, 3].T)
# Out:
#          0         1          2        3       4        5         6       7    \
# 0    16.7610   16.3540 -41.000000   -4.814  19.325   1.7564  -0.71937  94.954
# 1    40.1580   -5.3906 -42.318000  -12.427  22.122   2.5080  -0.74126  90.568
# 2    60.8360  -26.1630 -44.472000  -19.433  22.694   3.1096  -0.73002  80.879
# 3    77.8180  -44.2330 -47.411000  -25.825  21.520   3.3849  -0.76403  66.840
# 4    90.5510  -58.8200 -50.752000  -31.838  19.150   3.2361  -0.90182  49.244
# ..       ...       ...        ...      ...     ...      ...       ...     ...
# 495 -10.6320 -102.6800  -1.684800  144.790  66.239  23.6940 -51.75000  66.107
# 496  -9.5618 -117.4700  -1.564200  149.550  57.552  16.3240 -43.26800  58.992
# 497  -8.6192 -132.4200   0.050176  151.550  47.298   9.5449 -33.90400  51.210
# 498  -8.1654 -146.4100   3.931400  150.750  34.316   2.7638 -24.39000  42.692
# 499  -8.5101 -157.7900  10.919000  147.870  18.164  -4.2810 -15.43300  33.560
#
# ...

# %%
avel
# Out:
#          0        1         2        3        4         5         6    \
# 0    0.33522  0.32708 -0.820000 -0.09628  0.38649  0.035128 -0.014387
# 1    0.80317 -0.10781 -0.846360 -0.24854  0.44244  0.050160 -0.014825
# 2    1.21670 -0.52326 -0.889440 -0.38867  0.45387  0.062193 -0.014600
# 3    1.55640 -0.88466 -0.948220 -0.51651  0.43040  0.067697 -0.015281
# 4    1.81100 -1.17640 -1.015000 -0.63676  0.38299  0.064721 -0.018036
# ..       ...      ...       ...      ...      ...       ...       ...
# 494 -0.23029 -1.76410 -0.012654  2.76340  1.48690  0.647240 -1.170900
# 495 -0.21264 -2.05360 -0.033695  2.89580  1.32480  0.473890 -1.035000
# 496 -0.19124 -2.34930 -0.031285  2.99090  1.15100  0.326480 -0.865370
# 497 -0.17238 -2.64840  0.001004  3.03110  0.94595  0.190900 -0.678080
# 498 -0.16331 -2.92830  0.078629  3.01500  0.68633  0.055276 -0.487790
#
#          7         8         9    ...       318      319       320       321  \
# ...
